# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Refer to the line gragh for concluding; Capomulin and Ramicane, had the most mice testing conducted
# - Refer to the scatter plot graphs for concluding; Capomulin treatment for mice results in a lower chance of tumor for average weight the longer the treatment is given, however those results dwindle when the individule mouse is larger in size/weight.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
Combine_DATA = pd.merge(mouse_metadata, study_results, how='right')

# Display the data table for preview
Combine_DATA = Combined_data[['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites', 
                               'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)']]

Combine_DATA.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
Mice = Combine_DATA["Mouse ID"].value_counts()
Mice_NUM =len(Mice)
Mice_NUM
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
Mice_dup = Combine_DATA.loc[Combine_DATA.duplicated(subset=['Mouse ID', 'Timepoint',]),'Mouse ID'].unique()
Mice_dup
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
Mice_dup_DF = Combine_DATA.loc[Combine_DATA["Mouse ID"] == "g989", :]
Mice_dup_DF
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
CLEANdf = Combine_DATA[Combine_DATA['Mouse ID'].isin(Mice_dup)==False]
CLEANdf.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
CLEAN_MICE =CLEANdf["Mouse ID"].value_counts()
CLEAN_NUM =len(CLEAN_MICE)
CLEAN_NUM
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

REG_mean = CLEANdf.groupby('Drug Regimen').mean()["Tumor Volume (mm3)"]
REG_median = CLEANdf.groupby('Drug Regimen').median()["Tumor Volume (mm3)"]
REG_variance = CLEANdf.groupby('Drug Regimen').var()["Tumor Volume (mm3)"]
REG_std = CLEANdf.groupby('Drug Regimen').std()["Tumor Volume (mm3)"]
REG_sem = CLEANdf.groupby('Drug Regimen').sem()["Tumor Volume (mm3)"]



# Assemble the resulting series into a single summary DataFrame.

STAT_TAB_SUM = pd.DataFrame({"Mean Tumor Volume": REG_mean, 
                                    "Median Tumor Volume":REG_median, 
                                    "Tumor Volume Variance":REG_variance, 
                                    "Tumor Volume Std. Dev.": REG_std, 
                                    "Tumor Volume Std. Err.":REG_sem })

STAT_TAB_SUM
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
SUM_AGG = CLEANdf.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['mean', 'median', 'var', 'std', 'sem'])
SUM_AGG
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
COUNT_MICE = CLEANdf["Drug Regimen"].value_counts()

PLOT_P = COUNT_MICE.plot.bar(color='tab:red') 

# create the titles and labels.
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.title("Number of Mice per Treatment")

plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
X_AXIS = COUNT_MICE.index.values
Y_AXIS = COUNT_MICE.values

#Pyplot bar plot pluse label & the title
plt.bar(X_AXIS, Y_AXIS, color='tab:green', alpha=0.8, align='center')

# create the titles and labels.
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.xticks(rotation ="vertical")
plt.title("Number of Mice per Treatment")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

GENDATA = CLEANdf["Sex"].value_counts()
GENDATA.plot.pie(autopct= "%1.10f%%")
plt.title("Female vs. Male Mice")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

SIZE = [49.7999197, 50.200803]
LABLE = ['Female', 'Male']
PLOT = GENDATA.plot.pie(y='Total Count', autopct="%1.10f%%")
plt.ylabel('Sex')
plt.title("Female vs. Male Mice")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

EACH_MOUSE = Combine_DATA.groupby(["Mouse ID"]).max()
EACH_MOUSE_R = EACH_MOUSE.reset_index()

MDATA = EACH_MOUSE_R[['Mouse ID','Timepoint']].\
    merge(Combine_DATA,on =['Mouse ID','Timepoint'],how ="left")

def FIND_Outliers(Regimen):
    RDATA = MDATA.loc[MDATA["Drug Regimen"] == Regimen]['Tumor Volume (mm3)']
    
    QUART = RDATA.quantile([.25,.5,.75])
    QUART_ONE = QUART[0.25]
    QUART_END = QUART[0.75]
    QUART_RANGE = QUART_END - QUART_ONE
    LOWB = QUART_ONE - (1.5 * QUART_RANGE)
    HIGHB = QUART_END + (1.5 * QUART_RANGE)

    outliers = RDATA.loc[(RDATA < LOWB) | (RDATA > HIGHB)]
    print(f"{Regimen}'s potential outliers:{outliers}")
    return RDATA
    
CAP = FIND_Outliers("Capomulin")
RAM = FIND_Outliers("Ramicane")
CEF = FIND_Outliers("Ceftamin")
INF = FIND_Outliers("Infubinol")
# Out:
# Capomulin's potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ceftamin's potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers:31    36.321346
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
DLIST = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
DRUGS = Combine_DATA[Combine_DATA["Drug Regimen"].isin(DLIST)]
DRUGS.head()


# Start by getting the last (greatest) timepoint for each mouse
TIMEPLOT_L = DRUGS.groupby(["Drug Regimen", "Mouse ID"]).agg(SIZET=("Tumor Volume (mm3)", lambda x: x.iloc[-1]))
TIMEPLOT_L = TIMEPLOT_L.stack(level=0).unstack(level=0)

# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

TREATMENT = 0
for DRUG in DLIST:
    QUART = TIMEPLOT_L[DRUG].quantile([.25,.5,.75]).round(2)
    LOWQ = QUART[0.25].round(2)
    UPPERQ = QUART[0.75].round(2)
    IQ = round(UPPERQ-LOWQ,2)
    LOWB = round(LOWQ - (1.5*IQ),2)
    UPPERB= round(UPPERQ + (1.5*IQ),2)

    if TREATMENT == 0:
        print(f"------------------------------------------------------------")
    print(f"The lower quartile of {DRUG} treatments is: {LOWQ}")
    print(f"The upper quartile of {DRUG} treatments is: {UPPERQ}")
    print(f"The interquartile range of {DRUG} treatments is: {IQ}")
    print(f"Values below {LOWB} could be {DRUG} outliers.")
    print(f"Values above {UPPERB} could be {DRUG} outliers.")
    print(f"------------------------------------------------------------")
    TREATMENT+=1
# Out:
# ------------------------------------------------------------
# The lower quartile of Capomulin treatments is: 32.38
# The upper quartile of Capomulin treatments is: 40.16
# The interquartile range of Capomulin treatments is: 7.78
# Values below 20.71 could be Capomulin outliers.
# Values above 51.83 could be Capomulin outliers.
# ------------------------------------------------------------
# The lower quartile of Ramicane treatments is: 31.56
# The upper quartile of Ramicane treatments is: 40.66
# The interquartile range of Ramicane treatments is: 9.1
# Values below 17.91 could be Ramicane outliers.
# Values above 54.31 could be Ramicane outliers.
# ------------------------------------------------------------
# The lower quartile of Infubinol treatments is: 54.05
# The upper quartile of Infubinol treatments is: 65.53
# The interquartile range of Infubinol treatments is: 11.48
# Values below 36.83 could be Infubinol outliers.
# Values above 82.75 could be Infubinol outliers.
# ...

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

BDOT = dict(markerfacecolor = "blUE", markersize=12)
plt.boxplot([RAM, CAP, CEF, INF],labels=['Capomulin','Ramicane','Infubinol','Ceftamin'],flierprops= BDOT)
plt.ylabel('Final Tumor Volume (mm3)')
plt.title('Tumor Volume at Selected Mouse')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
CAPdf = CLEANdf.loc[CLEANdf["Drug Regimen"] == "Capomulin",:]

LINEDF = CAPdf.loc[CAPdf["Mouse ID"] == "l509",:]
LINEDF.head()
X_AXIS = LINEDF["Timepoint"]
SIZET = LINEDF["Tumor Volume (mm3)"]

F1, A1 = plt.subplots()
plt.title('Capomulin treatmeant of mouse l509')
plt.plot(X_AXIS, SIZET,linewidth=1,color="purple", label="Fahreneit")
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
F1, A1 = plt.subplots()
CAP_AVERAGE_VOL =CAPdf.groupby(['Mouse ID']).mean()

DSIZE =1
plt.scatter(CAP_AVERAGE_VOL['Weight (g)'],CAP_AVERAGE_VOL['Tumor Volume (mm3)'], color="orange")
plt.xlabel('Weight (g)',fontsize =10)
plt.ylabel('Averag Tumor Volume (mm3)')
plt.title('Mouse Weight Versus Average Tumor Volume')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

CORR = st.pearsonr(CAP_AVERAGE_VOL['Weight (g)'],CAP_AVERAGE_VOL['Tumor Volume (mm3)'])
#print(f"The correlation between mouse weight and the average tumor volume is {round(CORR[0],2)}")


#the Capomulin regimen: 
#linear regression line 
#for mouse weight and average tumor volume calculate the correlation coefficient and linear regression 

(SLOPE, INTER, RV, PV, STDERR)=st.linregress(CAP_AVERAGE_VOL["Weight (g)"],CAP_AVERAGE_VOL["Tumor Volume (mm3)"])
RVALUES = CAP_AVERAGE_VOL["Weight (g)"]* SLOPE + INTER
LINE = f"y = {round(SLOPE, 2)} x + {round(INTER, 2)}"

plt.scatter(CAP_AVERAGE_VOL["Weight (g)"],CAP_AVERAGE_VOL["Tumor Volume (mm3)"],color='yellow')
plt.plot(CAP_AVERAGE_VOL["Weight (g)"], RVALUES, color='brown')
plt.annotate(LINE,(20,36), fontsize=10)
plt.title("Weight vs Tumor Volume for Capomulin")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
